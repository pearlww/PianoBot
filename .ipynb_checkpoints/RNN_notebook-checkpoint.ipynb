# %%
import numpy as np


# To read the training data and make a vocabulary and dictiornary to index the chars
class DataReader:
    def __init__(self, path, seq_length):
        #uncomment below , if you dont want to use any file for text reading and comment next 2 lines
        #self.data = "Mulţi ani trecură la mijloc de când aceşti fraţi nu mai avură prilej a se întâlni amândoi. Iară verii, adică feciorii craiului şi fetele împăratului, nu se văzuse niciodată de când erau ei. Şi aşa veni împrejurarea de nici împăratul Verde nu cunoştea nepoţii săi, nici craiul nepoatele sale: pentru că ţara în care împărăţea fratele cel mai mare era tocmai la o margine a pământului, şi crăia istuilalt la o altă margine. Şi apoi, pe vremile acelea, mai toate ţările erau bântuite de războaie grozave, drumurile pe ape şi pe uscat erau puţin cunoscute şi foarte încurcate."
        self.fp = open(path, "r")
        self.data = self.fp.read()
        #find unique chars
        chars = list(set(self.data))
        #create dictionary mapping for each char
        self.char_to_ix = {ch:i for (i,ch) in enumerate(chars)}
        self.ix_to_char = {i:ch for (i,ch) in enumerate(chars)}
        #total data
        self.data_size = len(self.data)
        #num of unique chars
        self.vocab_size = len(chars)
        self.pointer = 0
        self.seq_length = seq_length

    def next_batch(self):
        input_start = self.pointer
        input_end = self.pointer + self.seq_length
        inputs = [self.char_to_ix[ch] for ch in self.data[input_start:input_end]]
        targets = [self.char_to_ix[ch] for ch in self.data[input_start+1:input_end+1]]
        self.pointer += self.seq_length
        if self.pointer + self.seq_length + 1 >= self.data_size:
            # reset pointer
            self.pointer = 0
        return inputs, targets

    def just_started(self):
        return self.pointer == 0
    
    def close(self):
        self.fp.close()

# %%
data = "Mulţi ani trecură la mijloc de când aceşti fraţi nu mai avură prilej a se întâlni amândoi. Iară verii, adică feciorii craiului şi fetele împăratului, nu se văzuse niciodată de când erau ei. Şi aşa veni împrejurarea de nici împăratul Verde nu cunoştea nepoţii săi, nici craiul nepoatele sale: pentru că ţara în care împărăţea fratele cel mai mare era tocmai la o margine a pământului, şi crăia istuilalt la o altă margine. Şi apoi, pe vremile acelea, mai toate ţările erau bântuite de războaie grozave, drumurile pe ape şi pe uscat erau puţin cunoscute şi foarte încurcate."

# %%
def zero_init(num_rows, num_cols):
    return np.zeros((num_rows, num_cols))

# %%
char_to_ix = {ch:i for (i,ch) in enumerate(chars)}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f8d0ce006191> in <module>
# ----> 1 char_to_ix = {ch:i for (i,ch) in enumerate(chars)}
#
# NameError: name 'chars' is not defined

# %%
print(char_to_ix)
# Out:
# {'p': 0, 'g': 1, 'r': 2, 'd': 3, ' ': 4, 'i': 5, 'l': 6, 'M': 7, ':': 8, 'c': 9, 'e': 10, 'ţ': 11, 'b': 12, 'ş': 13, 'n': 14, ',': 15, 'u': 16, 'j': 17, 'v': 18, 't': 19, 'I': 20, 'z': 21, 'î': 22, 'm': 23, 'o': 24, 'â': 25, 'Ş': 26, 'V': 27, 'f': 28, 'ă': 29, 'a': 30, 's': 31, '.': 32}

# %%
ix_to_char = {i:ch for (i,ch) in enumerate(chars)}

# %%
print(ix_to_char)
# Out:
# {0: 'p', 1: 'g', 2: 'r', 3: 'd', 4: ' ', 5: 'i', 6: 'l', 7: 'M', 8: ':', 9: 'c', 10: 'e', 11: 'ţ', 12: 'b', 13: 'ş', 14: 'n', 15: ',', 16: 'u', 17: 'j', 18: 'v', 19: 't', 20: 'I', 21: 'z', 22: 'î', 23: 'm', 24: 'o', 25: 'â', 26: 'Ş', 27: 'V', 28: 'f', 29: 'ă', 30: 'a', 31: 's', 32: '.'}

# %%
data_size = len(data)

# %%
print(data_size)
# Out:
# 572

# %%
seq_length = 20 
pointer = 0
input_start = pointer
input_end = pointer + seq_length
inputs = [char_to_ix[ch] for ch in data[input_start:input_end]]
targets = [char_to_ix[ch] for ch in data[input_start+1:input_end+1]]
pointer += seq_length
if pointer + seq_length + 1 >= data_size:
    # reset pointer
    pointer = 0

# %%
print('inpputs',inputs)
print('targets',targets)
print(pointer)
print(pointer + seq_length)
# Out:
# inpputs [7, 16, 6, 11, 5, 4, 30, 14, 5, 4, 19, 2, 10, 9, 16, 2, 29, 4, 6, 30]
# targets [16, 6, 11, 5, 4, 30, 14, 5, 4, 19, 2, 10, 9, 16, 2, 29, 4, 6, 30, 4]
# 20
# 40

# %%
input_start = 20
input_end = 20 + seq_length
inputs = [char_to_ix[ch] for ch in data[input_start:input_end]]
targets = [char_to_ix[ch] for ch in data[input_start+1:input_end+1]]
pointer += seq_length

# %%
print('inpputs',inputs)
print('targets',targets)
print(pointer)
print(pointer + seq_length)
# Out:
# inpputs [4, 23, 5, 17, 6, 24, 9, 4, 3, 10, 4, 9, 25, 14, 3, 4, 30, 9, 10, 13]
# targets [23, 5, 17, 6, 24, 9, 4, 3, 10, 4, 9, 25, 14, 3, 4, 30, 9, 10, 13, 19]
# 60
# 80

# %%
class RNN:
    def __init__(self, hidden_size, vocab_size, seq_length, learning_rate):
        # hyper parameters
        self.hidden_size = hidden_size
        self.vocab_size = vocab_size
        self.seq_length = seq_length
        self.learning_rate = learning_rate
        # model parameters
        self.U = np.random.uniform(-np.sqrt(1./vocab_size), np.sqrt(1./vocab_size), (hidden_size, vocab_size))
        self.V = np.random.uniform(-np.sqrt(1./hidden_size), np.sqrt(1./hidden_size), (vocab_size, hidden_size))
        self.W = np.random.uniform(-np.sqrt(1./hidden_size), np.sqrt(1./hidden_size), (hidden_size, hidden_size))
        self.b = np.zeros((hidden_size, 1)) # bias for hidden layer
        self.c = np.zeros((vocab_size, 1)) # bias for output
        
        # memory vars for adagrad, 
        #ignore if you implement another approach
        self.mU = np.zeros_like(self.U)
        self.mW = np.zeros_like(self.W)
        self.mV = np.zeros_like(self.V)
        self.mb = np.zeros_like(self.b)
        self.mc = np.zeros_like(self.c)

    def softmax(self, x):
        p = np.exp(x- np.max(x))
        return p / np.sum(p)
        
    def forward(self, inputs, hprev):
            xs, hs, os, ycap = {}, {}, {}, {}
            hs[-1] = np.copy(hprev)
            for t in range(len(inputs)):
                xs[t] = zero_init(self.vocab_size,1)
                xs[t][inputs[t]] = 1 # one hot encoding , 1-of-k
                hs[t] = np.tanh(np.dot(self.U,xs[t]) + np.dot(self.W,hs[t-1]) + self.b) # hidden state
                os[t] = np.dot(self.V,hs[t]) + self.c # unnormalised log probs for next char
                ycap[t] = self.softmax(os[t]) # probs for next char
            return xs, hs, ycap
        
    def backward(self, xs, hs, ps, targets):
            # backward pass: compute gradients going backwards
            dU, dW, dV = np.zeros_like(self.U), np.zeros_like(self.W), np.zeros_like(self.V)
            db, dc = np.zeros_like(self.b), np.zeros_like(self.c)
            dhnext = np.zeros_like(hs[0])
            for t in reversed(range(self.seq_length)):
                dy = np.copy(ps[t])
                #through softmax
                dy[targets[t]] -= 1 # backprop into y
                #calculate dV, dc
                dV += np.dot(dy, hs[t].T)
                dc += dc
                #dh includes gradient from two sides, next cell and current output
                dh = np.dot(self.V.T, dy) + dhnext # backprop into h
                # backprop through tanh non-linearity 
                dhrec = (1 - hs[t] * hs[t]) * dh  #dhrec is the term used in many equations
                db += dhrec
                #calculate dU and dW
                dU += np.dot(dhrec, xs[t].T)
                dW += np.dot(dhrec, hs[t-1].T)
                #pass the gradient from next cell to the next iteration.
                dhnext = np.dot(self.W.T, dhrec)
            # clip to mitigate exploding gradients
            for dparam in [dU, dW, dV, db, dc]:
                np.clip(dparam, -5, 5, out=dparam) 
            return dU, dW, dV, db, dc
    
    def loss(self, ps, targets):
            """loss for a sequence"""
            # calculate cross-entrpy loss
            return sum(-np.log(ps[t][targets[t],0]) for t in range(self.seq_length))
        
    
    def update_model(self, dU, dW, dV, db, dc):
        # parameter update with adagrad
        for param, dparam, mem in zip([self.U, self.W, self.V, self.b, self.c],
                                  [dU, dW, dV, db, dc],
                                  [self.mU, self.mW, self.mV, self.mb, self.mc]):
            mem += dparam*dparam
            param += -self.learning_rate*dparam/np.sqrt(mem+1e-8) # adagrad update
                
                
    def sample(self, h, seed_ix, n):
            """
            sample a sequence of integers from the model
            h is memory state, seed_ix is seed letter from the first time step
            """
            x = zero_init(self.vocab_size, 1)
            x[seed_ix] = 1
            ixes = []
            for t in range(n):
                h = np.tanh(np.dot(self.U, x) + np.dot(self.W, h) + self.b)
                y = np.dot(self.V, h) + self.c
                p = np.exp(y)/np.sum(np.exp(y))
                ix = np.random.choice(range(self.vocab_size), p = p.ravel())
                x = zero_init(self.vocab_size,1)
                x[ix] = 1
                ixes.append(ix)
            return ixes

    def train(self, data_reader):
            iter_num = 0
            threshold = 0.01
            smooth_loss = -np.log(1.0/data_reader.vocab_size)*self.seq_length
            while (smooth_loss > threshold):
                if data_reader.just_started():
                    hprev = np.zeros((self.hidden_size,1))
                inputs, targets = data_reader.next_batch()
                xs, hs, ps = self.forward(inputs, hprev)
                dU, dW, dV, db, dc = self.backward(xs, hs, ps, targets)
                loss = self.loss(ps, targets)
                self.update_model(dU, dW, dV, db, dc)
                smooth_loss = smooth_loss*0.999 + loss*0.001
                hprev = hs[self.seq_length-1]
                if not iter_num%500:
                    sample_ix = self.sample(hprev, inputs[0], 200)
                    print( ''.join(data_reader.ix_to_char[ix] for ix in sample_ix))
                    print( "\n\niter :%d, loss:%f"%(iter_num, smooth_loss))
                iter_num += 1

    def predict(self, data_reader, start, n):

        #initialize input vector
        x = zero_init(self.vocab_size, 1)
        chars = [ch for ch in start]
        ixes = []
        for i in range(len(chars)):
            ix = data_reader.char_to_ix[chars[i]]
            x[ix] = 1
            ixes.append(ix)

        h = np.zeros((self.hidden_size,1))
        # predict next n chars
        for t in range(n):
            h = np.tanh(np.dot(self.U, x) + np.dot(self.W, h) + self.b)
            y = np.dot(self.V, h) + self.c
            p = np.exp(y)/np.sum(np.exp(y))
            ix = np.random.choice(range(self.vocab_size), p = p.ravel())
            x = zero_init(self.vocab_size,1)
            x[ix] = 1
            ixes.append(ix)
        txt = ''.join(data_reader.ix_to_char[i] for i in ixes)
        return txt

# %%
seq_length = 20
#read text from the "input.txt" file
data_reader = DataReader("/home/mj/input.txt", seq_length)
rnn = RNN(hidden_size=100, vocab_size=data_reader.vocab_size,seq_length=seq_length,learning_rate=1e-1)
rnn.train(data_reader)
# Out:
# îŞsvd vrăavgŞidăîŞmnâpd sesnA  ăvolr cCpajzCîavCni,tpns
#  t,elg săsăaîA ăobrApsvsŞşegîşîsvggrsul  şr  ădsnn v
# u jvsP
#   de-
#   cvr
#
# sât-agu if taăsvrâtl-ş ,-iiînsiugrg-şrŞeş
# gşsă,is răapşă
# ltŞtp îlâvâăl
#
#
#
# iter :0, loss:69.930164
# iuă iodăcăul
# grapenerul pe uumdui pere ce soue dtoe al că siârtr pe ni aale me ri p
# e ce deatotece sstosă ie îi aaaiorspese şişiud şosir, munşi i a şiui âse şe l re şiul cl i ssl pcur me de şssrştănm
#
#
# iter :500, loss:66.900897
# neânsasă, să pa paje se de ceaiai arcajun Ane. pe se atuă pagă, te
# pse şrul aoaiulrătoaraşă ajunsătăasşstle, lâsarstăcurânepizâssie şibeăteti
# tală săluAcai,
# ul popatrse arsibeesă ăe psecalniâne ră, va
#
#
# iter :1000, loss:58.334422
#  crînânsi
# pjnă înizecŞiPciafaPă, fzngospuiseoumde finiolulundzsi al ie Ae fiviAumuşzviululpininîe,
# dAînsiâce
# -surni cad ŞrouClpi, şPŞl fi-Pâie ânbrânde îndă
#  vinăzniunăăuCecătândndnde fenşiul velub,
# d
#
#
# iter :1500, loss:51.890237
# e avsărai îe itunse vrnăC şi bape ul ce şi
# iă um a pă se lesă aints  dul, d se
# iunumoi pumate, dole aacatepânttura să îrânte u se i  a riindzse frtă coas şişiule înPepeaiŞi câlpie, aiupunea te ie acă,
#
#
# iter :2000, loss:46.319990
# nide une madulu  înă fe îe v ca alcă fe însesăznd să, gă pl fleiul fgăurue ăunie ăula oea Şi
# calulâi ioşa al cape şl îna de ps lo ssgă pe ştânuedete se alapo Asău. Şi încândrsiase şi ainius, d. Agău.
#
#
# iter :2500, loss:38.494432
# ânume, depeptd. Şi nuşsu-rul
# te şi se ul calul ie âftcîl ca ce acad l se p capitului Şi dul şi se ascie alci balace messupaiaiului
# num lă, de şi încâl dopoînsău. vi, cainăub, încăl încalta capalul ie
#
#
# iter :3000, loss:30.484921
#  doumaite do ară îl ca de vunumaca aiulaptoască porndesă poa pap, înd.
# Şi spmpăuoainu săse aicststânu-să urb poşi dja şa ajunumsă aşd. Şi ce dă
# mete şi întu întral cepecâ-să
# iui
# ltânte ulci, şini ră
#
#
# iter :3500, loss:27.658698
# ti îndese încântând.e înde tre înăape încind nă se, viăă
# peav crând. Şi încur ce
# ă, încul, sea că însădăse, caca păunu s romea ceaicve capăcun cum capotri, săoi poai te
# ânteagtândas dtu-stre să- jeaea
#
#
# iter :4000, loss:27.158359
# le
# ai îa acapela mntrsecamaleiocăpecâsăinăiul cea şi se îlumaizne săşinlacumaipioroarpeundoupvine sura macâm soraitue că înaintelului să aşte şi aştoarub de urs, fisă te gă artă de porasău. Şi nu
# a fe
#
#
# iter :4500, loss:23.597643
#  sări, um să uns să um şi în poumpinăi, poruse
# umav forăindă um ie uratoinăind se uns maiptu-suse înseru-sciepode şi seul şi
# num ursdu, de şi înaină-susăurun ul craieînde, ne a năd piui Şi înteagă ulu
#
#
# iter :5000, loss:19.400938
# nă dadu pită cale dună tapumpi serumai lurie urstă, tât pă vengă el ie depine să calalui şi
# l feci în ceaca sădunău să ie altă să , ferutaină înde, d se înacă peniznă sea de urs moaptu-săul insăru să
#
#
# iter :5500, loss:15.231980
#  şiur ajunde,ede şi cât porate, ferde alel ia alul celouşină pe aluluiupteacale telu-său.-Şins, pes mnrnstruniuă nă d se Şi ajun urupe şi, pe înaincoloe şi
# i îndă, dădu, d se acate, se săui puciucaşiu
#
#
# iter :6000, loss:11.793867
# esede de şi câtăpi şi înrrta îndosăupând-săupse al, inse a te îndmunduluşlul fiului dndea depedocă
# pe ascunspânu-său.
# d, şi
# neîndrăznind a pto, foră-rătrtolofod a capoi caluiu se înd, pecalu-s mosăs ş
#
#
# iter :6500, loss:9.334090
#  scrape că finund răse îmbracă
# pe asci porapelucând spse întoarnăirum
# se şi înaşspiepindeaşi pt aitcalul înaimorenuns re doa săuo calul i, tea de urs şipiâmpi îl forină a capoeciulalul şi
# neîndrăznind
#
#
# iter :7000, loss:7.007715
# rioroardu şi aştepul strnumaietă-l ur fede venincmoi lu aite şiznumb alui pe îna fiul înculsindă
# podrai vecal te întoarnă,rumai a pacatb arta feciorusău pă îne malce cacăd săd se îndoresătoiulai, îlsc
#
#
# iter :7500, loss:6.632382
#   a îndecind să tumu-p ul urs îb atasă, dă vrâ-săuă, fitaşrnă racrnt aştepgt se b şi se pe calul şi, înt morăă un umai înăăunse melcea cea capătul podului, îl maiului pe altă parol şi
# njdnd se îna şi
#
#
# iter :8000, loss:5.081617
#  şiun înde pe acolo,
# numai iaca leca căaipe îndşi l, mor sătumoi întub trăipie
# trnubaină la mel, crai îu un traiciorus, drră
# numai iaca la înărutrină ruşinăta sea de urs şi iumba capă pide şi ajunsese
#
#
# iter :8500, loss:3.851184
#
# i ateiul capormtr ae încalt ai, dăăundă  să baptrunapoi aşped d a, începe a sări, coeoumaipe mul peci
# das, dă pa pede şi vede pere ba calul du tatu-săunse,pie îlecrlu aluiuşi
# nărumeînindă şi cât poru
#
#
# iter :9000, loss:2.977480
#  sări în două picioartă ta cra pe înserate, se îmbracă
# pe a cale săui pepi bal, dese şi ara doduse îmbrace
# de ursitâtă, tese înaintă, d, întoarnă rumaitrinăi
# trniosese ba ca îna sciltăteas ândesă piel
#
#
# iter :9500, loss:3.572838
# dăduse
# drnini,
# umpă pind să urgă înainte, seciorusău. Şi numai iaca îa şi vede venind repede, d, şi altă cale şi se bagă sub un pede ând. ni stătând-săupâe aită pa algă caaşv asăul iulu l dă porului î
#
#
# iter :10000, loss:2.788162
#  şi
# iâcace
# năb aine rul bai în moi sere mol îl şi vede venină re dtui întă
# das se altă para şisă cal iapte şi cacntrre a moroarscroa sărinumb pe îne să izPână mai merge înaintea ntoiulue dapină pore c
#
#
# iter :10500, loss:2.157437
# e oaci, urs morununs morend însă-putci
# dun, se îrse ai, aluşa se um îndun mornăind. Atunci
# calul fiului de crai începe a sări în două pidi peroaralui pe şipe însăd se îmbracă
# pe asci îndo
# pormoiolea î
#
#
# iter :11000, loss:1.714622
#  înaind se aca alui, şi ajunsese acasă, că ca şi lul şi
# l însă, vrd, numai iaca îl şi vede venind repede, dar nu aşa duptend să treape ace sie iea ce pe îna pe mortse încoace cre cie cose baeul şi tum
#
#
# iter :11500, loss:1.415375
# riolea de ul şi ajunu se acată, dăduse
# drumul calelui, îndmui cacă
# pe ască parte unsintrte île sielui în două picioarta cracolrăi îscroaca de al ă paraldiu-său se aca ca ul itatând să peele şi se bagă
#
#
# iter :12000, loss:1.192098
#  dă tatu-său.
# Până să ajungă el, craiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină fecioreartepunsiul foul, îl pore îndm iisă poatatr
#
#
# iter :12500, loss:1.031377
# ău. şi
# calul ind sărinrăspun poa ptund s se ajunsese aras în boars,ripe,.ibsea de înde pnsimiră,pe să ajungă el, craiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calul, şi ajunsese acasă, dădu
#
#
# iter :13000, loss:0.910257
# -l pouşsca ca feciorusău. Şi numai iaca îl şi vede veninderum săd a mera vini lu acum să vină orrnumai iaca morum îa pe ie aca ca pepe înd. cagă înte or pud a capătul pefi înăecind să treacă fiu-său p
#
#
# iter :13500, loss:0.819668
#  sări
# e pină
# numai iaca îl îsă, ve aratu-său. Şi înto-o pină iu ai, iese înainte ciacale, instruâlulsi, deacoerăindă pită pe întoarnă ru vină ajundedu porapea de şi seab al fife eaca calo, fintaău- ău
#
#
# iter :14000, loss:0.747212
# pe ge aină în aluă pod. cagă înteaă aşacând. Şi într-răacu-său pe auciocaaşi lurună poru întă ficioleău pe se ace ace să fiumoibaifiol ne oraiul şise rredrind st prderă butaintumgi îrainluped. Şi
# nuru
#
#
# iter :14500, loss:2.367639
#  şi ioru v tape pe calului, nerndrăursăd. Şi fină rum sesă, ve cape altă cale şi se maltum şi, pe fece a Şi ajunsese acasă, dăduse
# drumul calului, îndouise piolalul şine însă, vrând să-l ispitească, t
#
#
# iter :15000, loss:3.337044
# , înaintoaită pe întoarnă ruşinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de altă partea de şi cât pe ce sepincalul fiului de crai începe a sări în două pi îeaşind ai înde, deaindmaiceascul ş
#
#
# iter :15500, loss:2.383960
#  înepsă creace cie arnttă re întoarnă ruşinat înaită cale şa fecia şi
# vedi mera molul pe întoarnă rnde de alcă para de craiul craiului, nemaiputând se cal şi vede venind repedea fooioluf de urs şi aşt
#
#
# iter :16000, loss:1.730875
# ând struni calul şi cât , ficiorusău pe altă cale şi se bagă să incalului, îndosise pielea cea de urs şi aştepta atum vjsău al, îlscul şi vediri la teajde capnteatu-său
# sedluuti, pndosise pielea cea d
#
#
# iter :16500, loss:1.302419
# , feciorusău. Şi numai iaca la cea de urs şi aştepta acum să vină feciorusău. ri, şiea capătul ia vecă
# nea de urs şi aştepta acum iacă
# poum iacape capotun şi înad um înă race
# de ursiul fiuluu se
# d a c
#
#
# iter :17000, loss:1.019202
#  îna fiuă pecind să treacă fiu-său pe acolo,
# numai iaca la capătul podului îl şi întâmpină un urs mornăind. Atunci
# calul cale şi se bagă sub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca la c
#
#
# iter :17500, loss:0.829281
# -l ispitească, tace molcum şi, pe înserate, se îmbracă
# duniub urs mornăind. Atunci
# calul calelui şi cepe sări în două picioare, indă
#  în poroarte se înaintea feciorusău pe altă cale şi se bagă sub un
#
#
# iter :18000, loss:0.700047
#  sări înainuşsău. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai merge înainte, se întoarnd ruse, de ce să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiput înă-lgă ci, şi când se
#
#
# iter :18500, loss:0.610383
# nă alelui, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa duptul pe co sepintraună piciorusău. Şi fiul craiului, nemulaiul cra desădu
#
#
# iter :19000, loss:0.546241
#  doue aicioare, ă da dult moi în întoarnă ruşinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de altă parte şi ajunsese acasă, dăduse
# di îl întrânu-său. Şi fiul craiului, nemaiputând se aasăun po
#
#
# iter :19500, loss:0.500116
# i în întoarnă ra năăinu, şi cât pe ce să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
# leîncă
# pe ascuns într-o piele de urs, apoi încalecă pe cal, iisă înatatu-său.
# Până să aj
#
#
# iter :20000, loss:0.465206
#  întângă ul, craiul pe de altă parte şi ajunsese uratrtu-său. Şi numai iaca la capătpiul şi vâne se île ba casău-său.
# Până scând să treacă fiu-său pe ascuns întolă piele drs mornăipional, tetă-lul cur
#
#
# iter :20500, loss:0.435310
# oi alcind re întie crao al, iese înaintea fece cumoiciorupuu  cas în două pi într-o pieluă ur iecuosea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa dup
#
#
# iter :21000, loss:0.410870
#  un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca îl şi vede venind repede, dar nu aşa dupu te craiul ie acatuinum ind să treacă fiu-său pe acolo,
# numai iaca îl şi vede venind repede, dar nu aşa
#
#
# iter :21500, loss:0.389462
# ău selo calul ursi, îndmse încase înalscilsă cale şi poaca fiu-său pe acolo,
# numai iaca îl şi vede venind repede, dar nu aşa dupe se şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de ur
#
#
# iter :22000, loss:0.371387
# -l ispitească, tace molcum iese altă cale şi se bagă sub un pod. Şi încrse, de crai începe a sări în două , cisă lură murapul, ve secă fiui de crai începe a sări în două picioare, forăind, şi cât pe c
#
#
# iter :22500, loss:0.355167
#  săriâ. cioralul fiulaiuluă nă de arsă fe uns mornăipind să treacă fiu- da de şi aştepta acrmel, pipinde Şi când să treacă fiu-său pe acolo,
# numai iaca îl şi vede venind repede, dar nu aşa dupe se doa
#
#
# iter :23000, loss:0.340472
# dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca la capătul podului îl şi întâmpină un urs mornăind. Atunci
# calul fiului de crai începe a sări în cal
#
#
# iter :23500, loss:0.327721
#  de ie, cndă vrăi înră poră,
# dmul ii întoarnă rumelaiu-său pe acolo,
# numai iaca îl şi vede venind repede, dar nu aşa dupe se aşserumai iora molci pe stăpânu-său. Şi fiul craiului, nemaiputând struni c
#
#
# iter :24000, loss:0.316287
# i aicioa e, forăind, şi cât pe ce să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai merge înainte, se întoarnă ra peate, se îmbracă
# pe ascuns într-o piele de
#
#
# iter :24500, loss:0.305937
#  înetrtrăi taca îl ispună pioi mară desă-l ispitească, tace molcum şi, pe înserate, se îmbracă
# pe ascuns într-o piele de urs, apoi încalecă pe cal, iese înaintea feciorusău pe altă cale şi se bagă sub
#
#
# iter :25000, loss:0.296733
# rincal i şi ajdns maiputând struni calul şi
# neîndrăznind a mai merge înainte, se întoarnă ruşinat înapoi la tre malul craiul us înpe şi aâfice înă să ajungă el, craiului, umoira înde pnd. piele de urs
#
#
# iter :25500, loss:0.287706
#  şi ajunsese acasă, dăduse
# drvint teperusă, să înă stă, serate, se îmbra în de craită, macalui, teacrloă vrntrău-p ică
# pe altă peră începe aesă calcia cea de urs şi aşdea de înaiscraoub şi întâmpină u
#
#
# iter :26000, loss:0.278938
# ău. ci
# drfine umoi peca întete, se îmbracă
# pe asău acă farinderepede, dar înde intaltătunu-să- ce să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai merge îna
#
#
# iter :26500, loss:0.270585
# -l ispitească, tace molcum şi, pe înserate, se îmbracă
# pe ascuns într-o piele de urs, apoi încalecă piele de urs, apoi încalecă pe cal, iese înaintea feciorusău pe altă cale şi se bagă sub un pod. Şi
#
#
# iter :27000, loss:0.264755
#  sărisăup umei île, forăind, şi cât pe ce să
# izbească pe stăpânu-său. Şi fiul craiuiui, nemaiputând struni calul şi
# neîndrăznind a mai merge înainte, se întoarnă ruşinat maiputci lerscindă pit a ca ce
#
#
# iter :27500, loss:0.256882
# pede, dznind a mai meltul şi întâmpină un urs mornăind. Atunci
# calul fiului de crai începe a sări în două picioare, forăind, şi cât pe ce să
# izbească pe stăir-a elttânu-să treaca maiuiaşi îndel maipun
#
#
# iter :28000, loss:0.250961
#  şizne să ajungă el, craiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa
#
#
# iter :28500, loss:0.245633
# ta desă pielea dă , încesă pte, se îmbracă
# pe ascununăi vrŞi numai iaca la cată,pum calcalătumpi la la îl îndă, d depe aintea ficiorusău  ajungă el, craiul pe de altă parte şi ajunsese acasă, dăduse
# d
#
#
# iter :29000, loss:0.240017
#  într-o piele de urs, îns s, înaipte drunumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca lo moi încalecă pe cal, iese înaintea feciorusău pe altă fiului At t
#
#
# iter :29500, loss:0.234384
# rină fecea de ura şi într-o ângă el, craiul pe de altă partepe ae înse, îngese, de şi vede venind repede, dar nu aşa dului, iese înaintea feciorusău pe altă cale şi se băuă numaiului, trâns
# capunui c
#
#
# iter :30000, loss:0.230244
# , ne întoarnă ruşinaufecea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa dupu a cacea acolo,
# numai iaca la capătul podului îl şi întâmpină un arsă ateău
#
#
# iter :30500, loss:0.224700
# ău pecă pe calul şi
# neîndrăznind a mai merge înainte, se întoarnă ruşinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea d
#
#
# iter :31000, loss:0.219613
#  aică pe staipmalul pe ce acolode şi aştepti înepânu-său. Şi numai ia alui drsiul, vinursu-l ur delumpitasăt. Până să ajdndă  să pntiub porunuşs se al şi nu-său. Şi numai merge al, un um ie aco pcolol
#
#
# iter :31500, loss:0.609542
#  sără în fiul craiului, ulsă caleă tepe bage întoarnă ruşinat însera pe te, forăind rndepid să, dăduse
# drumul calului, îndosise picăa în acasă, dă psiul fiul,, te ce să
# izbească pe stăpânu-său. Şi fiu
#
#
# iter :32000, loss:3.784597
# de, fe cape pe ală, d du-i iacub un ul şi vade vrninnirumaiuluura decă
# de ai ium ltăpe pe înserate, fecăa leinde şi câodăiu îngă îlai înaisărfiu acalului, îndosise pielea cea de urs şi aştepta acum să
#
#
# iter :32500, loss:2.561936
#  două picioare, forăind, şi cât pe ce să
# izbească pe stăuşizni calul şi
# neîndrăznind a mai merge înainte, serioroarse se întoarnă ruşinatata acum să vină feciorusău. Şi numai iaca latcă pe stăpânu-său
#
#
# iter :33000, loss:1.741713
# e acel cape tatu-său.
# Până să aine să apoi încalecă pe cal, iese înaintea feciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca le de urs şi aştepta acum să vin
#
#
# iter :33500, loss:1.215257
#  ioar aipe ai înserate, se îmbracă
# pe ascuns într-o piele de urs, apoi încalecă pe cal, iese înaintea feciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca la c
#
#
# iter :34000, loss:0.879190
# oiob anun ul iupe al fiuluiud ună ruşinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină fe
#
#
# iter :34500, loss:0.665073
# , sepe a sări în două picioase, da cr altă parteaşf
# căounina atu- cacă
# pe îsău  altiacaltă pa teaşd aiula ună facină se bagă sub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca îl şi vede venin
#
#
# iter :35000, loss:0.525862
# cunsealul cal în boarale craiul pe de alcă parnă aitioruruş bagt a mai merge înaint a ficioane, de îndusă calulsi, peră molcum şi, pe înserate, se îmbracă
# pe asce se apoi încalecă pe cal, iese înainte
#
#
# iter :35500, loss:0.434585
# -e asăun pud u, a căa şacă fiu-său pe acolo,
# numai iaca la capătul podului îl şi întâmpină un urs mornăind. Atunci
# calul şi
# neîndrăznind a mai merge înainte, se întoarnă ruşinat înapoi la tatu-său.
# Pâ
#
#
# iter :36000, loss:0.373692
#  sări în doa sări în două picioare, forăind, şi câtcind, şi cât pe ce să
# izbească pe întâmoi se alol fiul urs mornăind. Atunci
# calul fiului de crai înce şi ajunsese acasă, dăduse
# drumul calulud um s s
#
#
# iter :36500, loss:0.331253
# dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca la capătul podului îl şi întâmpină un urs mornăind. Atunci
# calul fiului de crai începe a sări în dou
#
#
# iter :37000, loss:0.301130
#  întoarnă ruşinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca
#
#
# iter :37500, loss:0.278109
# i, capătul podului îl şi întâmpină un urs mornăind. Atunci
# calul fiului de crai începe a sări în două picioare, forăind, du înd. şi ajunsese să ind,
# drdtse baecoa îl înendă
# put
# nd inrupede, dar nu aşa
#
#
# iter :38000, loss:0.259914
#  foul urs îl itatendesu ai mece molcum şi, pe însemaiput să tând să treacă fiutui duci, îl co, în înapou se aită fiul iisi, visemora dăun Şicioa sări înciorumăi şi
# nera dăui în două picioare, forăind,
#
#
# iter :38500, loss:0.246028
# oindea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca la capătul podului îl şi întâmpină un urs mornăind. Atunci
# calul fiului de crai începe a sări în două picioare, forăind, şi cât pe c
#
#
# iter :39000, loss:0.235246
# inună vini se înserate, se îmbracă
# pe asci pe alsă parnă aiuî casă, dăunsese înaipăd te, fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai merge înainte, se întoarnă ruşinatatu-său.
# Până s
#
#
# iter :39500, loss:0.226028
# ă piciorusăun şi înaipunci
# calul cale şi se bagă sub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca îl şi vede venind repede, dar nu aşa dupe pe porasă treaca capoină, vrge ciaipse şi ajunsese
#
#
# iter :40000, loss:0.218092
# -l ispitească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai merge înainte, se întoarnă ruşinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de altă parte şi ajun
#
#
# iter :40500, loss:0.210241
#  sărisealul, craiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai m
#
#
# iter :41000, loss:0.203176
# dă, de ca şi se oacum îalul te, se îmbracă
# pe ascuns într-o piele de urs, apoi încalecă pe cal, iese înaintea feciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său , strindar îu aşa
#
#
# iter :41500, loss:0.197300
#  şi cât pe ce să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai merge înainte, secioa sărizuneisece, se
# draşa stutrdu-z îlainăpoinizîtă, se îmbracă
# pe ascuns
#
#
# iter :42000, loss:0.192341
# e să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai merge înainte, se întoarnc scă pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind
#
#
# iter :42500, loss:0.188109
#  înatepul, îndos să ajunuisi
# loată să altă ale, se îmbracă
# pe ascuns într-o piele de urs, apoi încalecă pe cal, iese înaintea feciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său p
#
#
# iter :43000, loss:0.184509
# oinăealcă pe îneorapeaşi sou. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai merge înainteuşiznitumoicum ies, al ispiui calului, îndosise pielea cea de urs şi aştepta acum să vină fe
#
#
# iter :43500, loss:0.181171
# iul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa dupu a de crnumai iaca
#
#
# iter :44000, loss:0.177262
# ău. ci cape molce duîl da ula ficioara de aică fiu-său pe acolo,
# numai iaca la capătul podului îl şi întâmpină un urs mornăind. Atunci
# calul fiului de crai începe a sări în două picioare, forăind, şi
#
#
# iter :44500, loss:0.173585
# -l ispiteascrape şi cât pornă se înaintea feciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca la capătul podului îl şi întâmpină un urs mornăind. Atunci
# calul
#
#
# iter :45000, loss:0.169753
#  săripeacind aşd aşteptuasu ai, iese înaintea feciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca la capătul podului îl şi întâmpină uă urs morrăzcinseacum în
#
#
# iter :45500, loss:0.165504
# pe cape pe calul fiul urs moinăind. Atunci
# calul fiul ia alul ,
# derune înaisă ficioare, forăind, şi cât pe ce să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind a m
#
#
# iter :46000, loss:0.161689
#  drune,sizPu-răzâi le scăină a mai merge înaintău se şi încăse
# leposăsăzni, Atodea de uns mcalui şi
# ncînaşfioloă d lu ail de şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aşt
#
#
# iter :46500, loss:0.158288
# ib arb ul picioare, forăind, şi cât pe ce să
# izbeascalupaiulaşintrsesă
# poialuă parnăindepuse a asă, dăduse
# drum altă şi crascuns înăintalul forăind, şi cât pe ce să
# izbească ptând struni cal ai îndete
#
#
# iter :47000, loss:0.155344
#  întâmoiul podului îl şi întâmpină un urs mornăind. Atunci
# calul fiului de şi vede venind repede, dar nu aşa dupiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de ur
#
#
# iter :47500, loss:0.153091
# rindeatu a înd. Atonci
# calul fiului de crai începe a sări în două picioare, forăind, şi cât pe ce să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calui şi
# neînsă
# i fea şini în unui, d
#
#
# iter :48000, loss:0.151311
# iulud das na acumel, ciacalul fieiu îl şi vede venind repede, darunui şi întâmpină un urs mornăind. Atunci
# calul fiului de crai începe a sări în două picioare, forăind, şi cât pe ce să
# izbească pe stă
#
#
# iter :48500, loss:0.149202
# ău. Atrnă ruşinat înapoi la tatu-său.
# Până să ajunsea dea deaşind sepe a moraselte cal, iese înaintea de şi ajunsese acasă, vă aielui, îndoscsnumai începe a sări în două pini ptra catea fecaicum şi, p
#
#
# iter :49000, loss:1.296584
# -l aspău-l mainiâlu să isăi şi al îndrăznind a mai merge înainte, se întoarnă ruşinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de unsernă a ci caluluă pnd să pe şi ajunsese acasă, dăduse
# drumu
#
#
# iter :49500, loss:0.934657
# laiulu, pe cra de urs şi aştepta acum să vină feciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca la capătul poduldi, dese şi ajunsese acasă, dăd. Şi cnscrnd,
#
#
# iter :50000, loss:0.678080
# dăduse
# dăumul calului, îndosise pielea cea de urs şi aşpefgă dulăi, iise înainte, se întoarnă ruşinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de altă parte şi ajunsese acasă, dăduse
# drumul ca
#
#
# iter :50500, loss:0.510508
#  doununsine,piol a pe înde porapel ia ulsi, veînd ă, ststâe calcia de, dă ună ouşinat înapoi la tatu-său.
# Până să ajungă el, craiul pe drăipinsă-p indşs mornăăun şi întândmui pecalnt un urs mornăind.
#
#
# iter :51000, loss:0.388158
# e ale şi se b tă iub atut unrintalu pe calul şi
# neîndrăznind a mai merge înainte, se întoarnă ru aşa du întea feciorusău. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai merge înainte
#
#
# iter :51500, loss:0.306615
#  înto-o piele de urs, apoi încalecă pe cal, iese înaintea feciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe a calul, îmel a ficioare, forăind, şi cât pe ce să
# izbească pe stă
#
#
# iter :52000, loss:0.252223
# ândepese întoarnă ruşinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi num
#
#
# iter :52500, loss:0.215557
# iulutepui, înde tatu-său.
# Până să apoi încalecă pe cal, iese înaintea feciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca îl şi veca venind repede, secins se
#
#
# iter :53000, loss:0.189873
# cund aş mal în şipe mord, uns se acea se înto
# nă-l podului îl şi întâmpină un ursi, înge şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de al, dase
# pândnseru aşa d piră pe casăind. Atun
#
#
# iter :53500, loss:0.171608
# -l ispitească, tace molcum şi, pe înserate, se îmbracă
# pe ascuns într-o piele de urs, apoi încalecă pe cal, iese înaintea feciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe ac
#
#
# iter :54000, loss:0.157887
#  sădo ăacuns aluă ul şi, Şi când să pe cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca la capătul podului îl şi întâmpină un urs mornăind. Atunci
# calul fiului de crai începe a sări în dou
#
#
# iter :54500, loss:0.147076
# dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venină ru sub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca la capătul podului î
#
#
# iter :55000, loss:0.138530
#  şisiuă fide şi înăşi venind a ce ceaite strndosătune maipiine încascuns într-o cagă se,
# doumpumai iaca îl şi vede venind repede, dar nu aşa dupe însă
# pjunseagă îl ie acă, îngă pită, ieal forăindă vrn
#
#
# iter :55500, loss:0.131490
# e altă ptea cagă înaintea feciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca la capătul podului îl şi întâmpină un urs mornăind. Atunci
# calul fiului de crai
#
#
# iter :56000, loss:0.125573
#  întoa tea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa dupiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi
#
#
# iter :56500, loss:0.120531
# oinăta nă feciolus, tacumesă vine nu aşaldu înte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu
#
#
# iter :57000, loss:0.116152
# iul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa după înde pe acolo,
# num
#
#
# iter :57500, loss:0.112147
#  aisă feciorusău. Şi numai iaca paducind să treacă fiu-său pe acolo,
# numai iaca la capătul podului îl şi întâmpină un urs mornăind. Atunci
# calul fiului de crai începe a sări în două picioare, forăind,
#
#
# iter :58000, loss:0.108597
# -l ispitea capă pidă întum îm,rvarni-lu aşd seruşinat înapoi la te şi feciorusău pe altă cale şi se bagă sub un pod. Şi când să mneaiul de ca şi întâmpin, în marnăind. Atunci
# calul fiului de cral ă pe
#
#
# iter :58500, loss:0.105402
#  săă şine se întoarnă ruşinat înap, înde drvinite însă
# pungă îlaă un intraică pe inteagă suba feciorua de ura de şi ajunsese acasă, dăduse îmbracă
# pe ascuns într-o piele de urs, apoi încalecă pe cal,
#
#
# iter :59000, loss:0.102507
# dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa dupe însera acai în euulultie cea de unci
# calul fiului de crai
#
#
# iter :59500, loss:0.099905
#  şi ajunsese acasă, dăduse
# drumul calu-ică îne, începe a sări în două picioare, forăind, şi cât pe ce să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai merge
#
#
# iter :60000, loss:0.098294
# ipite, fi îndurune, se îmbracă
# pe ascuns într-o piele de urs, apoi încalecă pe cal, iese înaintea feciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca la capăt
#
#
# iter :60500, loss:0.095799
#  înto-o piele de urs, apoi încalecă pe cal, iese înaintea feciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca la capătul podului îl şi întâmpină un urs mornăi
#
#
# iter :61000, loss:0.093750
# oinăta cal, iese înaintea feciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe altă parnă aită, paca îl şi vede venind repede, dar nu aşa dupiul pe de altă parte şi ajunsese aca
#
#
# iter :61500, loss:0.091815
# iulu-său. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai merge înainte, se întoarnă ruşinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de altă parte şi ajunsese acasă, dăduse
# d
#
#
# iter :62000, loss:0.089900
# ău. d-să fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai merge înainte, se întoarnă ruşinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de altă parte şi ajunsese acasă, dăduse
# drumu
#
#
# iter :62500, loss:0.088122
# -l ii, îndosise pielea cea de ura şi întâmpină un urs mornăind. Atunci
# calul fiului de crai începe a sări în două picioare, forăind, şi cât pe ce să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiput
#
#
# iter :63000, loss:0.086452
# lsiul calul ie îmbracă
# pe ascuns într-o piele de urs, apoi încalecă pe cal, iese înaintea feciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca la capătul podul
#
#
# iter :63500, loss:0.084917
# dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa după îe urainu. şi când să treacă fiu-său pe acolo,
# numai iaca
#
#
# iter :64000, loss:0.083493
#  şi cât indeperule, forăind, şi cât pe ce să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai merge înainte, se întoarnă ruşinat înaloi la tatu-său.
# Până să aj
#
#
# iter :64500, loss:0.082164
# se, teape să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai merge înainte, se întoarnă ruşinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de altă parte
#
#
# iter :65000, loss:0.080894
#  stăpânu-s îld se sarină le tatu-său.
# Până să ajungă el, craiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca
#
#
# iter :65500, loss:0.079719
# ând struni calul şi
# neîndrăznind să tâmula înd. Atunci
# calul fiul irsini
# lu se ase, desă-l ispitească, tace molcum şi, pe înserate, se îmbracă
# pe ascuns într-o piele de urs, apoi încalecă pe cal, iese
#
#
# iter :66000, loss:0.078571
# iulud das înde pe altă parte şi când d un arci încaltă să ajungă el, craiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi
#
#
# iter :66500, loss:0.077406
# ău
# pengă aşa şi ajdăse
# nciltum fe ascuns într-o piele de urs, apoi încalecă pe cal, iese înaintea feciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca la capăt
#
#
# iter :67000, loss:0.076317
# -l ispitească, tace molcum şi,iuă pe atearfeciorusău pe sealtă, pecepese săui pe sărnd, pe aca cal, iese înaintea decâte săripite, îneasindepese şimajunseruşinat înapoi la tatu-său.
# Până să ajungă el,
#
#
# iter :67500, loss:0.075261
#  să traloirum îe întrade şi cât pe ce să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai merge înainte, se întoarnă ruşinat înapoi la tatu-său.
# Până să ajungă
#
#
# iter :68000, loss:0.074287
# dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa dupu mur ii întoarnă ruşinat înapoi la tatu-său.
# Până să ajungă
#
#
# iter :68500, loss:0.073361
#  şi
# ijunse cală ul şi vede venind repede, dar nu aşa sure înseraca calătul şi vede venind repede, dar nu aşa dupiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de ur
#
#
# iter :69000, loss:0.072484
# i, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa dupiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea c
#
#
# iter :69500, loss:0.071622
#  înto-o piele de urs, apoi încalecă pe cal, iese înaintea feciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca la capătul podului îl şi întâmăină un arăira cap
#
#
# iter :70000, loss:0.070818
# ând struni calul şi
# neîndrăznind să treaca fe însesăd se întoarnă ruşinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea d
#
#
# iter :70500, loss:0.070007
# iulupe înd. Atunci
# calul fiului de crai începe a sări în două picioare, forăind, şi cât pe ce să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai merge înainte
#
#
# iter :71000, loss:0.069163
# dunun şo alu-p înd. Atunci
# deatul urs îndesăinde şi ajunsese araiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai i
#
#
# iter :71500, loss:0.068373
# -l ispitească, tace molcum şi, pe înserate, se îmbracă
# pe ascuns într-o piele de urs, apoi încalecă pe cal, iese înainteaşfeciol să treaca se  cal, iese înaintea feciorusău pe altă cale şi se bagă sub
#
#
# iter :72000, loss:0.067593
#  sări în două picioare, serum înapoinăiul cas se înainde şipe însptape acal moracă- deduse, d să vună nu aşa duport calcra de aină ateaumul, craiul pe de altă parte şi ajunsese acasă, dăduse
# drumul ca
#
#
# iter :72500, loss:0.066873
# dădude îmbracă
# pe ascuns într-o piele de urs, apoi încalecă pe cal, iese înaintea feciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca la capătul podului îl şi
#
#
# iter :73000, loss:0.066184
#  şiznd. Atunci
# calul fiului de crai începe a sări în două picioare, forăind, şi cât pe ce să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai merge înainte, se
#
#
# iter :73500, loss:0.065527
# i în două picioare, forăind, şi cât pe ce să
# izbeascul şi vede venind repede, dar nu aşa dupu a de şi vede venind repede, dar nu aşa după îl şi încmainstai al îl şi întâmpină un urs mornăind. Atunci
# c
#
#
# iter :74000, loss:0.064868
#  înto-o piele de urs, apoi încalecă pe cal, iese înaintea feciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca la capătul podului îl şi întâmpină un urs mornăi
#
#
# iter :74500, loss:0.064256
# oinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede v
#
#
# iter :75000, loss:0.063624
# iul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa după însera a asă, dădu
#
#
# iter :75500, loss:0.062958
# ă . cind să treacă fiu-său pe acolo,
# numai iaca la capătul podului îl şi întâmpină un urs şi aştepta acum să vină feciomoră,pi, teto-său. Şi numai iaca îl şi vede venind repede, dar nu aşa după înde p
#
#
# iter :76000, loss:0.062337
# -l prăiul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa după însera a pe îndur se în aldă viu-său pe acolo,
# numai iaca la c
#
#
# iter :76500, loss:0.061714
#  sări înră, dâficioate, forăind, şi cât pe ce să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai merge înainte, se întoarnă ruşinat înapoi la tatu-său.
# Până s
#
#
# iter :77000, loss:0.061144
# dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa după înde pe acolo,
# numai iaca la capătul podului îl şi întâmpi
#
#
# iter :77500, loss:0.060596
#  deun tearte strnd. ci
# calul fiului de crai începe a sări în două picioare, forăind, şi cât pe ce să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai merge îna
#
#
# iter :78000, loss:0.060071
# i în două picioarnumui pecale, iacună ru aşa dupiul pe de altă parte şi când săstâesepe catata îndis moi fe îl şi vede venind repede, dar nu aşa după înde pe altă partă cale şa alul, înde iele întoarn
#
#
# iter :78500, loss:0.059535
#  înto-o piele de urs, apoi încalecă pe cal, iese înainte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de ursă ină pt altă parnăda caput itunum altă cale şi se bagă sub un pod. Şi când
#
#
# iter :79000, loss:0.059039
# rinătsuăpie aiului îmaită înde pe acolo,
# numai iaca îl şi vede venind repede, dar nu aşa după însera a teputău aca de şi într-o piele de urs, apoi încalecă pe cal, iese înaintea feciorusău pe altă cal
#
#
# iter :79500, loss:0.058518
# iul ăiscrlo,pul pedecâmprse fe cal, iese înaintea feciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca la ce scoină a mai merge înaintea feciorusău. Şi numai i
#
#
# iter :80000, loss:0.057965
# ău. de de al ă parăe pornainserumel, craiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind re
#
#
# iter :80500, loss:0.057449
# -l ispitească, tace molcum şi, pe înserate, se îmbracă
# pedu pe îl şi întâmpină un urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa dupi în pul şi
# neîndrăznind
#
#
# iter :81000, loss:0.056925
#  sări în două picioare, forăind, şi cât pe ce să
# izbeacea feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa dupiuî  ndas nu aşa dupu ge înaintea feciorusău. Şi numai iaca îl şi se întoarn
#
#
# iter :81500, loss:0.056449
# nă înăisă fecior să treacă fiu-său pe acolo,
# numai iaca la capătul podului îl şi întâmpină un ară ruşinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de altă parunse capătul şi vede venind repede
#
#
# iter :82000, loss:0.055989
#  şisib umbiacă
# po şi foul urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa după îl şite încind să treacă fiu-său pe acolo,
# numai iaca la capătul podului îl şi
#
#
# iter :82500, loss:0.055546
# ie şi înderite, forăind, şi cât pe ce să
# izbeascrapu-păum
# i, şine înse, de ca şi se bagă sub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca la capoi într-o piele de urs, apoi încalecă pe cal,
#
#
# iter :83000, loss:0.055084
#  înto ptânsecă
# poumaiu-, a pe înserate, se îmbracă
# pe ascuns într-o câtumaiul ură mul calul de îrbiui pecarăa îndă, d dus, umoi altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe acolo,
# num
#
#
# iter :83500, loss:0.054658
# rină-s, pită caserasca mai merge înainte, se întoarnă ruşinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, încalelusa te şi ajunsese acasă,
#
#
# iter :84000, loss:0.054203
# iul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa după înde pe altă parte
#
#
# iter :84500, loss:0.053722
# ă pidă poră de cearum înaşi, şi cât altumaiul şi întâmpină un urs mornăind. Atunci
# calul şi
# neîndrăznind a mai merge înainte, se întoarnă ruşinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de al
#
#
# iter :85000, loss:0.053268
# -l ind. Atuncilcă piciorapui şi ajunsese înai
# ne înai înde pe acolo,
# numai iaca îa şi, pe însera ptate, se îmbracă
# pe ascuns într-o piele de urs, apoi încalecă pe cal, iese înaintea feciorusău pe altă
#
#
# iter :85500, loss:0.052801
#  sări în două picioare, forăind, şi cât pe ce să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai merge înainte, se întoarnă ruşinat înapoi la tatu-său.
# Până s
#
#
# iter :86000, loss:0.052380
# dăduse, de crai începe a sări în două picioare, forăind, şi cât pe ce să
# izbească pe stătr,
# perea feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa după însera a te înde pe acând sere cra
#
#
# iter :86500, loss:0.051970
#  şiznd. Atunci
# calul fiului de crai începe a sări în două picioare, forăind, şi cât pe ce să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai merge înainte, se
#
#
# iter :87000, loss:0.051574
# i, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa dupiulup, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai i
#
#
# iter :87500, loss:0.051155
#  înto-o piele de urs, apoi încalecă pe cal, iese înaintea feciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca la capătul podului îl şi întâmpină un urs mornăi
#
#
# iter :88000, loss:0.050774
# oinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede v
#
#
# iter :88500, loss:0.050364
# iul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa dupiulupeduău. ci
# calul
#
#
# iter :89000, loss:0.049944
# ă pipi ceascal, iese înaint acă, şisă ajungă el, craiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi ve
#
#
# iter :89500, loss:0.049544
# -l ind. Atunci
# calul fiului de crai începe a sări în două picioare, forăind, şi cât pe ce să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai merge înainte, se
#
#
# iter :90000, loss:0.049137
#  sări în două picioare, forăind, şi cât pe ce să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai merge înainte, se întoarnă ruşinat înapoi la tatu-său.
# Până s
#
#
# iter :90500, loss:0.048782
# dăunse, de ca ştepul fiului iere scrle, se îmbracă
# pe ascuns într-o piele de urs, apoi încalecă pe cal, iese înaintea feciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe acolo,
#
#
# iter :91000, loss:0.048438
#  şiui înaind a mai merge înaindepus,
# numpi încaltă parte şi ajuns se aşa săui încraa acumpitapătul podusă un poi la îl şi vede venind repede, dar nu aşa după îl într-tua şi întâmpină un urs mornăind.
#
#
# iter :91500, loss:0.048109
# i în şi, şi câtd. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai merge înainte, se întoarnă ruşinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de altă parte şi ajunsese acasă,
#
#
# iter :92000, loss:0.047759
#  înetrtu-
# fioiolea cea de urs şi aştepta acumusăinde şi încă putapuns în morând sera alui înde ce să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai merge îna
#
#
# iter :92500, loss:0.047447
# oinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise piel a cea de şi într-o pieluşinum ie altă parte şi ajunsese acasă, d dun îndrăz
#
#
# iter :93000, loss:0.047109
# iul pe de altă peatcă pe stăpânu-său. Şi fiul craiului înaină ruşinat înaptincaltă pteajungă elti pe întrmorcind aşteasc ate şine înse, se îmbracă
# pe ascuns într-o piele de urs, apoi încalecă pe cal,
#
#
# iter :93500, loss:0.046766
# ău. dăge nsca caîntă-e de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acusă, vrviniului, nemaiputând struni calul şi
# neîndrăznind a mai merge înainte, se
#
#
# iter :94000, loss:0.046435
# -l ispitească, tace molcum şi, pe înserate, se îmbracă
# pe ascuns într-o piele de urs, apoi încalecă pe cal, iese înaintea feciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe ac
#
#
# iter :94500, loss:0.046097
#  sări în două picioare, forăind, şi cât pe ce să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai merge înainte, se întoarnă ruşinat înapoi la tatu-său.
# Până s
#
#
# iter :95000, loss:0.045807
# dăduse
# drumul calului Până să ajungă el, craius, cale şi se bagă sub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca la capătul podului îl şi întâmpină un urs mornăind. Atunci
# calul fiului de c
#
#
# iter :95500, loss:0.045523
#  şiznumai saduluşinat înapoialul şi
# neîndrăznind a mai merge înainte, se întoarnă ruşinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndos
#
#
# iter :96000, loss:0.045251
# mbracu-său pe acolo,
# numai iaca îl şi vede venind repede, dar nu aşa dupiuru puub ue uns să ajuns în artă rusiul fiul craiului, nemaiputând sădu-l irpită pe înaint a ficioare, forăind, şi cât pe ce să
#
#
# iter :96500, loss:0.044954
#  înto-o piele de urs, apoi încalecă pe cal, iese înaintea feciorusău pe altă cale şi se bagă stba feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa după îl porusău d  arăi la îl şi vede v
#
#
# iter :97000, loss:0.044692
# ând struni calul şi
# neîndrăznind a mai merge înainte, se întoarnă ruşinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea d
#
#
# iter :97500, loss:0.044403
# iul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa dupu se poră altă ptrăz
#
#
# iter :98000, loss:0.044112
# ău.uşinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi ve
#
#
# iter :98500, loss:0.043826
# -l ii, de îns maiputând struni calul şi
# neîndrăznind a mai merge înainte, se întoarnă ruşinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, î
#
#
# iter :99000, loss:0.043535
#  sări în două picioare, forăind, şi cât pe ce să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai merge înainte, se întoarnă ruşinat înapoi la tatu-său.
# Până s
#
#
# iter :99500, loss:0.043287
# dăduse
# drumui cape ase, de craiul craiul fiului de capătul şi vede venind repede, dar nu aşa dupu se şi ajunsese acasă, de ca şi i, unde şi ajdnse acalea feciorusău. Şi numai iaca îl şi vede venind re
#
#
# iter :100000, loss:0.043044
#  dfun maiputândepese înui
# iud, pecale, îndos se ai, iese înaintearfeciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca la capătul podului îl şi întâmpină un ur
#
#
# iter :100500, loss:0.042811
# e acolo,
# numai iaca îl şi vede venind repede, dar nu aşa dupu se prsernd lumpiele scra de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa dupu îe uraiu-a pu,
#
#
# iter :101000, loss:0.042552
#  înto-o piele de ursaunupe mai merge înainte, se întoarnă ruşinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de altă înemnipul i, îndnsese acasă, dtunl, pipău-său.
# Până scrnse se îlainteaiulrd,
#
#
# iter :101500, loss:0.042326
# oină
# numai iaca la capătul podului îl şi întâmpină un urs mornăind. te calul şi întea feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa după înde pe altă partă cale şi se bagă sub un pod.
#
#
# iter :102000, loss:0.042076
# , nursca p, îndmciolusău. Şi numai iaca îl şi vede venind repede, dar nu aşa după înde pe acolo,
# numai iaca la capătul podului îl şi întâmpină un urs mornăind. Atunci
# calul fiului de crai începe a săr
#
#
# iter :102500, loss:0.041825
# ău. cizcalul şi
# neîndrăznind a mai merge înainte, se întoarnă ruşinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de ur
#
#
# iter :103000, loss:0.041575
# -l aspătânumaininluşi leciorasultă pa tearfeciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca la capătul podului îl şi întâmpină un urs mornăind. Atunci
# calul
#
#
# iter :103500, loss:0.041322
#  sări în două picioare, forăind, şi cât pe ce să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
# ...
#
#
# iter :368000, loss:0.011195
# ă piciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca la capătul podului îl şi întâmpină un urs mornăind. Atunci
# calul fiului de crai începe a sări în două pi
#
#
# iter :368500, loss:0.011183
# -l ispitească, tace molcum şi, pe înserate, se îmbracă
# pe ascuns într-o piele de urs, apoi încalecă pe cal, iese înaintea feciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe ac
#
#
# iter :369000, loss:0.011163
#  sări în moa de baică pe într-o piele de urs, apoi încalecă pe cal, iese înaintea feciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca la capătul podului îl şi
#
#
# iter :369500, loss:0.011138
# dăduse
# drumul cas se înainde şi când să treacă fiu-său pe acolo,
# numai iaca la capătul podului îl şi întâmpină un urs mornăind. Atunci
# calul fiului de crai începe a sări în două picioare, forăind, şi
#
#
# iter :370000, loss:0.011123
#  şiul
# lea mai iaca îl şi vede venind repede, dar nu aşa dupu înse, dăduse
# drumul calului, îndosise pielea cea de urs şi aa catumbracă
# dru, pegă înacrtape ce să
# izbească pe stăpânu-său. Şi fiul craiul
#
#
# iter :370500, loss:0.011114
# e acolo,
# numai iaca îl ia tea feciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca la capătul podului îl şi întâmpină un urs mornăind. Atunci
# calul fiului de c
#
#
# iter :371000, loss:0.011097
#  înăi îndele craiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa dupt în
#
#
# iter :371500, loss:0.011081
# rini la îl şi vede venind repede, dar nu aşa dupi s, ind să treaca masăind să ajungă el, craiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să
#
#
# iter :372000, loss:0.011069
# iul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl io, încalecă pe cal, iese înaintea feciorusău pe altă cal
#
#
# iter :372500, loss:0.011036
#  întra ce să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai merge înainte, se întoarnă ruşinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de altă parte
#
#
# iter :373000, loss:0.011023
# -l ispitească, tace molcum şi, pe înserate, se îmbral îu dub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca la capătul podului îl şi întâmpină un urs mornăind. Atunci
# calul fiului de crai înce
#
#
# iter :373500, loss:0.011003
#  sări în nă n riciocul şi vede venind repede, dar nu aşa dupu însera acalului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca la capătul podului îl şi întâmpină un urs mo
#
#
# iter :374000, loss:0.010979
# dăduse
# drumul cas ta păd. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai merge înainte, se întoarnă ruşinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de altă parte şi ajunsese
#
#
# iter :374500, loss:0.010964
#  drue să iul ai ajcna se drue urs şi aştepta acum să vină feciorusău. Şi numai iaca la capătul podului îl şi întâmpină un urs mornăind. Atunci
# calul fiului de crai începe a sări în două picioare, foră
#
#
# iter :375000, loss:0.010955
# i, îl şi întâm de, da ul şina tepe acalui, îndeutsu,
# d. Atunci
# calul fiului de crai începe a sări în două picioare, forăind, şi cât pe ce să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiputând stru
#
#
# iter :375500, loss:0.010938
#  înto să-l iipită, teagă sub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca îl şi vede venind repede, dar nu aşa după înse,ad, picalcă parteaşfeciornind a de urs şi aşteage scaa acoirnamoi se
#
#
# iter :376000, loss:0.010923
# rini
# l se înapoi la tatu-său.
# Până să ajungă el, craiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi ve
#
#
# iter :376500, loss:0.010910
# iul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa după înse, de calul şin
#
#
# iter :377000, loss:0.010877
#  şicajuns maiputând struni calul şi
# neîndrăznind a mai merge înainte, se întoarnă ruşinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndos
#
#
# iter :377500, loss:0.010865
# -l ii, de şi întâmpină un urs mornăind. Atunci
# calul fiului de crai începe a sări în două picioare, forăind, şi cât pe ce să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
# neîn
#
#
# iter :378000, loss:0.010845
#  sărinumpininlum se,ci, nemaiputând struni calul şi
# neîndrăznind a mai merge înainte, se întoarnă ruşinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de altă parte şi ajunsese acasă, dăduse
# drumu
#
#
# iter :378500, loss:0.010821
# dăduse
# drunsise ajunuşsuîl de urs mornăind. Atunci
# calul fiului de crai începe a sări în două picioare, forăind, şi cât pe ce să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
#
#
#
# iter :379000, loss:0.010806
#  şiul
# lea pe înserutu-său pesă pină fiului desepede, dar nu aşa dupu îndusumaia şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca
#
#
# iter :379500, loss:0.010796
# i în înd  te şi ajunsese acasă, d de şi înăşi în întrai începe a sări în două picioare, forăind, şi cât pe cel şi vede venind repede, dar nu aşa dupi înd înd ă,pindaiului, sede şi ajunsese acasă, d se
#
#
# iter :380000, loss:0.010780
#  înto mal ra putaiul şi
# neîndrăznind a mai merge înainte, se întoarnă ruşinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea c
#
#
# iter :380500, loss:0.010765
# rini
# ne aiteaşie şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa duptum se acatearfeciorusău
#
#
# iter :381000, loss:0.010752
# iul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa după însă, venum
# ia şi
#
#
# iter :381500, loss:0.010720
# ă piciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca la capătul podului îl şi întâmpină un urs mornăind. Atunci
# calul fiului de crai începe a sări în două pi
#
#
# iter :382000, loss:0.010707
# -l aspăumpine se întoarnă ruse, înge şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa dupiul
#
#
# iter :382500, loss:0.010688
#  sări,
# ursău. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai merge înainte, se întoarnă ruşinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de altă parte şi ajunsese acasă, dădu
#
#
# iter :383000, loss:0.010664
# dăduse
# druşsă ne înainde şi ajunsese a asă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca la capătul podului îl şi întâmpină un urs mornăind. Atun
#
#
# iter :383500, loss:0.010649
#  drue să iul un înde şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa după ul ur pe calul şi
#
#
#
# iter :384000, loss:0.010640
# i în înde şi întâmpină un urs mornăind. Atunci
# calul fiului de crai începe a sări în două picioare, forăind, şi cât pe ce să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
# neîn
#
#
# iter :384500, loss:0.010623
#  întorrainde şi ajunsese acasă, dăduse
# drumul craiului înaină ruşinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de ur
#
#
# iter :385000, loss:0.010608
# rinioladul, iese înaintea feciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca la capătul podului îl şi întâmpină un urs mornăind. Atunci
# calul fiului de crai
#
#
# iter :385500, loss:0.010596
# iul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa dupiul pe de altă parte
#
#
# iter :386000, loss:0.010564
# ă .acincalul şi
# nuîninsepe, de calui şi ajunsese înainteaşf să para dese înaintea feciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca la capătul podului îl şi
#
#
# iter :386500, loss:0.010551
# -l ii, de şi întâmpină un urs mornăind. Atunci
# calul fiului de crai începe a sări în două picioare, forăind, şi cât pe ce să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
# neîn
#
#
# iter :387000, loss:0.010532
#  săăiulup, îl şi întâmpină un urs mornăind. Atunci
# calul fiului de crai începe a sări în două picioare, forăind, şi cât pe ce să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
#
#
#
# iter :387500, loss:0.010509
# dăduse
# dru, alcă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca la capătul podului îl şi întâmpină un urs mornăind. Atunci
# calul fiului de crai începe a sări în două picioa
#
#
# iter :388000, loss:0.010494
#  ursină n maiputând struni calul şi
# neîndrăznind a mai merge înainte, se înto-o piele de şi înăşi vede venind repede, dar nu aşa după înseta atăiul calul, înde trea alui, însesăsă,pind aşpe şi se bagă
#
#
# iter :388500, loss:0.010485
# i în înă at începefe scra fece ce scoltă pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca la capătul podului îl şi întâmpină un urs mornăind. Atunci
# calul fiului de c
#
#
# iter :389000, loss:0.010469
#  înto oacă fintra feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa dupi înte
# cre în urs mornăind. Atunci
# calul fiului de crai începe a sări în două picioare, forăind, şi cât pe ce să
# izb
#
#
# iter :389500, loss:0.010454
# rini
# l se însărună să apoi încalecă pe cal, iese înainteacaporună mul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu lul şi
# neîn
#
#
# iter :390000, loss:0.010442
# iul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa dupiul pe de altă parte
#
#
# iter :390500, loss:0.010411
# ă piciorusău dă tând sgă vină ruseşi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa după întel ficăacalui ia ul şi înăă pe altă cale şi se bagă sub un pod. Şi când
#
#
# iter :391000, loss:0.010398
# -l ispitească, tace molcum şi, pe înserate, se îmbracă
# pe ascuns într-o piele de urs, apoi încalecă pe cal, iese înaintea feciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe ac
#
#
# iter :391500, loss:0.010379
#  sări ouraşteitaa calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa dupiul pe de altă parte şi ajunsese acasă, dăduse
# drumul ca
#
#
# iter :392000, loss:0.010357
# dădusesă-l ispitească, tace molcum şi, pe înserate, se îmbracă
# pe ascuns într-o piele de urs, apoi îndosă ele dus şi aşteptralul şi
# neîndrăznind a mai merge înainte, se întoarnă ruşinat înapoi aştepta
#
#
# iter :392500, loss:0.010342
#  deai ne înaintea feciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe acolo,
# numai iaca la capătul podului îl şi întâmpină un urs mornăind. Atunci
# calul fiului de crai începe a
#
#
# iter :393000, loss:0.010333
# i, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca la capătul podului îl şi întâmpină un urs mornăind. Atunci
# calul fiului de crai începe a sări în două picioare, forăind,
#
#
# iter :393500, loss:0.010317
#  întorrum laca de al întoarnă ruşinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină fecior
#
#
# iter :394000, loss:0.010302
# rini
# l se însăd atrul ul încre capătul podului îl şi întâmpină un urs mornăind. Atunci
# calul fiului de crai începe a sări în două picioare, forăind, şi cât pe ce să
# izbească pe stăpânu-său. Şi fiul cr
#
#
# iter :394500, loss:0.010290
# iul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa după înse, de ce să
# izb
#
#
# iter :395000, loss:0.010259
#  şise pede pe altă parte şi ajunsese acasă, d se înainte, se întoro poel a pe însprini seaind repede, dar nu aşa dupiul pe de altă parte şi ajunsese acasă, dăduse
# drumul craiului, nemaiputând struni c
#
#
# iter :395500, loss:0.010247
# -l ispitească, tace molcum şi, pe înserate, se îmbracă
# pe ascuns într-o piele de urs, apoi încalecă pe cal, iese înaintea feciorusău pe altă cale şi se bagă sub un pod. Şi când să treacă fiu-său pe ac
#
#
# iter :396000, loss:0.010228
#  săui îna feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa dupu înstăină scă, ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi num
#
#
# iter :396500, loss:0.010206
# dăduse
# drunsise alene scalul fiului de crai începe a sări în două picioare, forăind, şi cât pe ce să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai merge îna
#
#
# iter :397000, loss:0.010191
#  drua te şi ajunsese acasă, dăduse
# drumul craiului fe al şi
# neîndrăznind a mai merge înainte, se întoarnă ruşinat înapoi la tatu-său.
# Până să ajungă el, craiul pe de altă parte şi ajunsese acasă, dădu
#
#
# iter :397500, loss:0.010183
# i în întând se în ascuns într-o piele de urs, apoi încalecă pe cal, iese înaintea feciorusău pe altă calea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu
#
#
# iter :398000, loss:0.010167
#  întorrainde şi ajunsese acasă, d de şi cât pe ce să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai merge înainte, se întoarnă ruşinat înapoi la tatu-său.
# Pâ
#
#
# iter :398500, loss:0.010153
# rini
# lasui pe acolo,
# dul inulaiulud ind,p de şi cât pe ce să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai merge înainte, se întoarnă ruşinat înapoi la tatu
#
#
# iter :399000, loss:0.010141
# iul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca maltum şi, pe înserate, se îmbracă
# pe ascuns într-o piele de
#
#
# iter :399500, loss:0.010111
#  und s
# ncalesă pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa după înd fzcioralul fiului de crai începe a sări în două picioare, forăind, şi
#
#
# iter :400000, loss:0.010098
# -l ii, cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca la capătul podului îl şi întâmpină un urs mornăind. Atunci
# calul fiului de crai începe a sări în două picioare, forăind, şi cât pe c
#
#
# iter :400500, loss:0.010080
#  săui îna fe întoarnă rnde capută mul, încaltă îneacca de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa dupiul pe de altă parte şi ajunsese acasă, dăduse
# d
#
#
# iter :401000, loss:0.010059
# dăduse
# drunsă altă perte şi ajunsese acasă, dăduse
# drumul calului, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa dupiul pe de altă p
#
#
# iter :401500, loss:0.010044
#  şiri în două picioare, forăind, şi cât pe ce să
# izbească pe stăpânu-său. Şi fiul craiului, nemaiputând struni calul şi
# neîndrăznind a mai merge înainte, se întoarnă ruşinat înapoi la tatu-său.
# Până s
#
#
# iter :402000, loss:0.010036
# i, îl, îndosise pielea cea de urs şi aştepta acum să vină feciorusău. Şi numai iaca îl şi vede venind repede, dar nu aşa dupiul pe de altă parte şi ajunsese acasă, dăduse
# drumul calului, îndosise piel
#
#
# iter :402500, loss:0.010020

# %%
rnn.predict(data_reader, 'get', 50)
# Out:
# 'getă, pie ptra pe să a al, dăui pe scro aicioa sărnd.'

# %%
rnn.predict(data_reader, 'fiul', 100)
# Out:
# 'fiule şi vad, piră,pe vecate, îl şi întâmpină un urs mornăind. Atunci\ncalul fiului de crai începe a sări'
